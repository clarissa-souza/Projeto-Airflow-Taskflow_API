# %% [markdown]
# <a href="https://colab.research.google.com/github/clarissa-souza/Projeto-Extensao-Airflow/blob/main/Extensao_airflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Bibliotecas
import pandas as pd
import zipfile
import requests
import os

# %%
# Download do arquivo
os.makedirs ('dadosOriginais',exist_ok = True)
url='https://download.inep.gov.br/microdados/microdados_censo_da_educacao_superior_2018.zip'
response = requests.get(url, verify=False).content
open('dadosOriginais/microdados_censo_da_educacao_superior_2018.zip','wb').write(response)
# Out:
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# 13216969

# %%
#Ver os arquivos dentro do zip
with zipfile.ZipFile ('dadosOriginais/microdados_censo_da_educacao_superior_2018.zip') as z:
  print(*z.namelist(), sep='\n')
# Out:
# Microdados do Censo da Educaç╞o Superior 2018/
# Microdados do Censo da Educaç╞o Superior 2018/Anexos/
# Microdados do Censo da Educaç╞o Superior 2018/Anexos/ANEXO I - Dicionário de Dados/
# Microdados do Censo da Educaç╞o Superior 2018/Anexos/ANEXO I - Dicionário de Dados/dicionário_dados_educaç╞o_superior.xlsx
# Microdados do Censo da Educaç╞o Superior 2018/Anexos/ANEXO I - Dicionário de Dados/~$Dicionário de Dados da Educaç╞o Básica.xlsx
# Microdados do Censo da Educaç╞o Superior 2018/Anexos/ANEXO I - Dicionário de Dados/~$dicionário_dados_educaç╞o_superior.xlsx
# Microdados do Censo da Educaç╞o Superior 2018/Anexos/ANEXO I - Dicionário de Dados/~$dicionário_dados_educaç╞o_superior_V1_clodoaldo.xlsx
# Microdados do Censo da Educaç╞o Superior 2018/Anexos/ANEXO II -  Questionários do Censo da Educaç╞o Basica/
# Microdados do Censo da Educaç╞o Superior 2018/Anexos/ANEXO II -  Questionários do Censo da Educaç╞o Basica/ANEXO II - MαDULO ALUNO 2018.pdf
# ...

# %%
#ver as colunas dentro do arquivo csv que eu quero
with zipfile.ZipFile ('dadosOriginais/microdados_censo_da_educacao_superior_2018.zip') as z:
  with z.open('Microdados do Censo da Educaç╞o Superior 2018/dados/MICRODADOS_CADASTRO_CURSOS_2018.CSV') as f:
    df=pd.read_csv(f, encoding='ISO-8859-1',sep=';', nrows=0)

# %%
df
# Out:
# Empty DataFrame
# ...

# %%
columns = ['NU_ANO_CENSO','NO_REGIAO','SG_UF','TP_GRAU_ACADEMICO','QT_VG_TOTAL','QT_INSCRITO_TOTAL']
with zipfile.ZipFile ('dadosOriginais/microdados_censo_da_educacao_superior_2018.zip') as z:
  with z.open('Microdados do Censo da Educaç╞o Superior 2018/dados/MICRODADOS_CADASTRO_CURSOS_2018.CSV') as f:
    df=pd.read_csv(f,encoding='ISO-8859-1',sep=';', usecols=columns)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (1,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df
# Out:
#         NU_ANO_CENSO NO_REGIAO SG_UF  TP_GRAU_ACADEMICO  QT_VG_TOTAL  \
# 0               2018     Norte    RO                1.0         70.0
# 1               2018     Norte    RO                2.0         50.0
# 2               2018     Norte    RO                1.0        100.0
# 3               2018     Norte    RO                1.0        100.0
# 4               2018     Norte    RO                1.0        100.0
# ...              ...       ...   ...                ...          ...
# 182887          2018       NaN   NaN                1.0          NaN
# 182888          2018       NaN   NaN                2.0          NaN
# 182889          2018       NaN   NaN                1.0          NaN
# 182890          2018       NaN   NaN                3.0          NaN
# 182891          2018       NaN   NaN                3.0          NaN
#
#         QT_INSCRITO_TOTAL
# 0                    40.0
# 1                   114.0
# 2                    55.0
# 3                    40.0
# ...
